# %% [markdown]
# <h1><center> CT Reporting Rates </center></h1>

# %%
import pandas as pd
import numpy as np
import calendar

# %%
# Declare the From and To Dates
FromDate = pd.to_datetime("2021-05-01")
ToDate = pd.to_datetime("2021-05-31")
# ToDate = pd.to_datetime(FromDate) + pd.offsets.MonthEnd()+pd.DateOffset(days=5)
print('From Date: ',FromDate,'To Date: ',ToDate)
# Out:
# From Date:  2021-05-01 00:00:00 To Date:  2021-05-31 00:00:00

# %% [markdown]
# ### Import the data
# - This is data on reporting for all the Active EMR Sites and those that reported in the last 12 months

# %%
rr = pd.read_csv("C:/Users/Admin/Desktop/Reporting Rates/ReportingRatesCTRaw_Mysql.csv")
rr.head()
# Out:
#    DisplayMFL     DisplayFacilityName DisplaySubcounty DisplayCounty  \
# 0       17431  AIC Kalamba Dispensary          Makueni       MAKUENI
# 1       17431  AIC Kalamba Dispensary          Makueni       MAKUENI
# 2       17431  AIC Kalamba Dispensary          Makueni       MAKUENI
# 3       17431  AIC Kalamba Dispensary          Makueni       MAKUENI
# 4       17431  AIC Kalamba Dispensary          Makueni       MAKUENI
#
#   DisplayMechanism DisplayAgency                               UploadStatus  \
# 0  CHAK CHAP Uzima           CDC  Both Care & Treatment + PKV(MPI) uploaded
# 1  CHAK CHAP Uzima           CDC             Only Care & Treatment Uploaded
# 2  CHAK CHAP Uzima           CDC             Only Care & Treatment Uploaded
# 3  CHAK CHAP Uzima           CDC  Both Care & Treatment + PKV(MPI) uploaded
# 4  CHAK CHAP Uzima           CDC             Only Care & Treatment Uploaded
#
#    UploadDate Upload_monthYear  SiteCode  MPI_SiteCode UploadDate_MPI  \
# 0  04/06/2021           Apr-21   17431.0       17431.0     04/06/2021
# 1  08/03/2020           Aug-20   17431.0           NaN            NaN
# 2  12/08/2020           Dec-20   17431.0           NaN            NaN
# 3  02/04/2021           Feb-21   17431.0       17431.0     02/04/2021
# 4  07/04/2020           Jul-20   17431.0           NaN            NaN
#
#   Upload_monthYear_MPI
# 0               Apr-21
# 1                  NaN
# 2                  NaN
# 3               Feb-21
# 4                  NaN

# %%
rr.shape
# Out:
# (13154, 13)

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13154 entries, 0 to 13153
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DisplayMFL            13154 non-null  int64
#  1   DisplayFacilityName   13154 non-null  object
#  2   DisplaySubcounty      13154 non-null  object
#  3   DisplayCounty         13154 non-null  object
#  4   DisplayMechanism      13154 non-null  object
#  5   DisplayAgency         13144 non-null  object
#  6   UploadStatus          13154 non-null  object
#  7   UploadDate            13107 non-null  object
#  8   Upload_monthYear      13107 non-null  object
#  9   SiteCode              13107 non-null  float64
#  10  MPI_SiteCode          6252 non-null   float64
#  11  UploadDate_MPI        6252 non-null   object
#  12  Upload_monthYear_MPI  6252 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Data Cleaning
# - Convert Dates to correct data types
# - Replace NULL with NA's
# - Remove Duplicates (Grouped by MFLCode and UploadDate)

# %%
rr=rr.replace({'NULL':np.NaN})

# %%
# Columns with NULLS
rr.columns[rr.isna().any()].tolist()
# Out:
# ['DisplayAgency',
#  'UploadDate',
#  'Upload_monthYear',
#  'SiteCode',
#  'MPI_SiteCode',
#  'UploadDate_MPI',
#  'Upload_monthYear_MPI']

# %%
#convert the upload_date and Upload_date MPI field from object to datetime datatype
rr['UploadDate'] = pd.to_datetime(rr['UploadDate'])
rr['UploadDate_MPI'] = pd.to_datetime(rr['UploadDate_MPI'])

# %%
rr.tail()
# Out:
#        DisplayMFL DisplayFacilityName DisplaySubcounty DisplayCounty  \
# 13149       18743    Kariobangi EDARP   Embakasi North       NAIROBI
# 13150       18743    Kariobangi EDARP   Embakasi North       NAIROBI
# 13151       18743    Kariobangi EDARP   Embakasi North       NAIROBI
# 13152       18743    Kariobangi EDARP   Embakasi North       NAIROBI
# 13153       18743    Kariobangi EDARP   Embakasi North       NAIROBI
#
#       DisplayMechanism DisplayAgency                    UploadStatus  \
# 13149            EDARP           CDC  Only Care & Treatment Uploaded
# 13150            EDARP           CDC  Only Care & Treatment Uploaded
# 13151            EDARP           CDC  Only Care & Treatment Uploaded
# 13152            EDARP           CDC  Only Care & Treatment Uploaded
# 13153            EDARP           CDC  Only Care & Treatment Uploaded
#
#       UploadDate Upload_monthYear  SiteCode  MPI_SiteCode UploadDate_MPI  \
# 13149 2021-03-23           Mar-21   18743.0           NaN            NaT
# 13150 2021-05-21           May-21   18743.0           NaN            NaT
# 13151 2020-11-10           Nov-20   18743.0           NaN            NaT
# 13152 2020-10-14           Oct-20   18743.0           NaN            NaT
# 13153 2020-09-21           Sep-20   18743.0           NaN            NaT
#
#       Upload_monthYear_MPI
# 13149                  NaN
# 13150                  NaN
# 13151                  NaN
# 13152                  NaN
# 13153                  NaN

# %%
#Remove Duplicates from original dataset - Unique Site with 1 Upload Date, upload MPI
rr = rr.drop_duplicates(subset=["DisplayMFL","UploadDate"])
rr.shape
# Out:
# (13140, 13)

# %%
# Create a column called UploadedCT & UploadedMPI
rr['uploadedCT'] = np.where(rr.UploadDate.isnull(),0,1)
rr['UploadedMPI'] = np.where(rr.UploadDate_MPI.isnull(),0,1)

# %% [markdown]
# ### Summary Statistics
# - How many Unique Facilities do we have (Number of Sites - Duplicates)

# %%
# Number of Unique EMR Sites - Denominator/ Expected Uploads
len(pd.unique(rr['DisplayMFL']))
# Out:
# 1392

# %% [markdown]
# <h2><center> Expected Uploads </center></h2>

# %%
#Create a data Frame to hold distinct list of sites for the denominator / Baseline EMR Sites
#We will use later for left joining
rr_denom = rr.drop_duplicates(subset=['DisplayMFL'])
rr_denom=rr_denom[['DisplayMFL','DisplayFacilityName','DisplaySubcounty','DisplayCounty','DisplayMechanism','DisplayAgency']]
rr_denom.head()
# Out:
#     DisplayMFL       DisplayFacilityName DisplaySubcounty DisplayCounty  \
# 0        17431    AIC Kalamba Dispensary          Makueni       MAKUENI
# 13       12860  AIC Zombe  Health Centre       Kitui East         KITUI
# 27       22059     Alwalidayn Dispensary        Msambweni         KWALE
# 40       22085       Athi Mission Clinic      Kitui South         KITUI
# 53       11936  Athi River Health Centre       Athi River      MACHAKOS
#
#                   DisplayMechanism DisplayAgency
# 0                  CHAK CHAP Uzima           CDC
# 13                 CHAK CHAP Uzima           CDC
# 27  Bomu Hospital Affiliated Sites           CDC
# 40                 CHAK CHAP Uzima           CDC
# 53                      CHS Naishi           CDC

# %%
rr_denom.shape
# Out:
# (1392, 6)

# %% [markdown]
# <h2><center> CT RECENCY </center></h2>

# %%
#Filter the Original RR Data to the specific RR Period (FromDate ToDate)
mask = (rr['UploadDate'] >= FromDate) & (rr['UploadDate'] <= ToDate)
recency=rr.loc[mask]
recency.shape
# Out:
# (1168, 15)

# %%
#Number of Duplicates in CT_Recency Those that reported in the reporting month and between 1st and 5th of next month
len(recency['DisplayMFL'])- len(pd.unique(recency['DisplayMFL']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('DisplayMFL', 'DisplayMechanism')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-fea7f84fc426> in <module>
#       1 #Number of Duplicates in CT_Recency Those that reported in the reporting month and between 1st and 5th of next month
# ----> 2 len(recency['DisplayMFL','DisplayMechanism'])- len(pd.unique(recency['DisplayMFL','DisplayMechanism']))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: ('DisplayMFL', 'DisplayMechanism')

# %%
#Remove duplicates.Making Sure we are counting a site only once within the reporting period being looked at
recency = recency.drop_duplicates(subset=["DisplayMFL"])
recency.shape
# Out:
# (1168, 15)

# %%
#Join the CT Recency Dataset to the EMR Sites Denominator - #Left Join
result = pd.merge(rr_denom,
                 recency[['DisplayMFL', 'UploadDate','uploadedCT']],
                 on='DisplayMFL', 
                 how='left')
result.shape
# Out:
#   File "<ipython-input-18-125ae37d51a2>", line 4
#     on='DisplayMFL','DisplayMechanism',
#                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# <h2><center> CT CONSISTENCY </center></h2>

# %%
# Define Period to compute 
consist_FromDate=pd.to_datetime(FromDate)-pd.DateOffset(months=2)
print('Consistency Period - From Date: ',consist_FromDate,'To Date: ',ToDate)
# Out:
# Consistency Period - From Date:  2021-03-01 00:00:00 To Date:  2021-05-31 00:00:00

# %%
#Filter the data to return - only sites that have Uploaded every month last 3 months
const = (rr['UploadDate'] >= consist_FromDate) & (rr['UploadDate'] <= ToDate)
consistency=rr.loc[const]
consistency.shape
# Out:
# (3352, 15)

# %%
#Pivot the Data then add instances of uploads by month, filter only those that uploaded all 3 months
cs=pd.pivot_table(consistency, values='uploadedCT', 
                    columns='Upload_monthYear',
                    index='DisplayMFL')

cs = cs.replace(np.nan, 0)
cs['UploadedConsistently']=cs.sum(axis=1) 
cs = cs.loc[(cs['UploadedConsistently']>=3)] 
cs.reset_index(inplace=True)# Flatten the table

#If Uploaded consistently is NULL then 0 other wise 1
cs['UploadedConsistently'] = np.where(cs.UploadedConsistently.isnull(),0,1)

cs
# Out:
# Upload_monthYear  DisplayMFL  Apr-21  Mar-21  May-21  UploadedConsistently
# 0                      10019     1.0     1.0     1.0                     1
# 1                      10049     1.0     1.0     1.0                     1
# 2                      10055     1.0     1.0     1.0                     1
# 3                      10100     1.0     1.0     1.0                     1
# 4                      10110     1.0     1.0     1.0                     1
# ..                       ...     ...     ...     ...                   ...
# 925                    22476     1.0     1.0     1.0                     1
# 926                    24200     1.0     1.0     1.0                     1
# 927                    24339     1.0     1.0     1.0                     1
# 928                    24969     1.0     1.0     1.0                     1
# 929                    25260     1.0     1.0     1.0                     1
#
# [930 rows x 5 columns]

# %%
#Join the Consistency Dataset to the CT Recency - #Left Join
result = pd.merge(result,
                 cs[['DisplayMFL', 'UploadedConsistently']],
                 on='DisplayMFL', 
                 how='left')
result.shape
# Out:
# (1392, 9)

# %%
result
# Out:
#       DisplayMFL           DisplayFacilityName  DisplaySubcounty  \
# 0          17431        AIC Kalamba Dispensary           Makueni
# 1          12860      AIC Zombe  Health Centre        Kitui East
# 2          22059         Alwalidayn Dispensary         Msambweni
# 3          22085           Athi Mission Clinic       Kitui South
# 4          11936      Athi River Health Centre        Athi River
# ...          ...                           ...               ...
# 1387       17548            EDARP Njiru Clinic          Kasarani
# 1388       17719  EDARP Komarock Health Centre  Embakasi Central
# 1389       18219      St Alice (EDARP) Dandora          Kasarani
# 1390       18409      St Veronica EDARP Clinic         Kamukunji
# 1391       18743              Kariobangi EDARP    Embakasi North
#
#      DisplayCounty                DisplayMechanism DisplayAgency UploadDate  \
# 0          MAKUENI                 CHAK CHAP Uzima           CDC 2021-05-04
# 1            KITUI                 CHAK CHAP Uzima           CDC 2021-05-05
# 2            KWALE  Bomu Hospital Affiliated Sites           CDC 2021-05-17
# 3            KITUI                 CHAK CHAP Uzima           CDC 2021-05-05
# 4         MACHAKOS                      CHS Naishi           CDC 2021-05-06
# ...            ...                             ...           ...        ...
# 1387       NAIROBI                           EDARP           CDC 2021-05-13
# 1388       NAIROBI                           EDARP           CDC 2021-05-19
# 1389       NAIROBI                           EDARP           CDC 2021-05-18
# 1390       NAIROBI                           EDARP           CDC 2021-05-21
# 1391       NAIROBI                           EDARP           CDC 2021-05-21
#
#       uploadedCT  UploadedConsistently
# 0            1.0                   1.0
# 1            1.0                   1.0
# 2            1.0                   1.0
# 3            1.0                   1.0
# 4            1.0                   1.0
# ...          ...                   ...
# 1387         1.0                   NaN
# 1388         1.0                   NaN
# 1389         1.0                   NaN
# 1390         1.0                   NaN
# 1391         1.0                   NaN
#
# [1392 rows x 9 columns]

# %% [markdown]
# ### Reporting Rates by County

# %%
byCounty=(result.groupby(['DisplayCounty'])
   .agg({'DisplayCounty':'count','uploadedCT': 'sum','UploadedConsistently':'sum'})
   .rename(columns={'DisplayCounty':'ExpectedUpload','uploadedCT' : 'CT Recently Uploaded','UploadedConsistently' : 'CT Consistency' })
         )
byCounty.reset_index(inplace=True)# Flatten the table
byCounty['Recency%']=(byCounty['CT Recently Uploaded']/byCounty['ExpectedUpload'])
byCounty['Consistency%']=(byCounty['CT Consistency']/byCounty['ExpectedUpload'])
byCounty=byCounty [['DisplayCounty','ExpectedUpload','CT Recently Uploaded','Recency%','CT Consistency','Consistency%']]
byCounty
# Out:
#       DisplayCounty  ExpectedUpload  CT Recently Uploaded  Recency%  \
# 0           BARINGO              11                  11.0  1.000000
# 1             BOMET              23                   3.0  0.130435
# 2           BUNGOMA              24                  24.0  1.000000
# 3             BUSIA              23                  19.0  0.826087
# 4   ELGEYO MARAKWET               9                   3.0  0.333333
# 5              EMBU              21                  12.0  0.571429
# 6          HOMA BAY             170                 148.0  0.870588
# 7            ISIOLO               1                   0.0  0.000000
# 8           KAJIADO              20                  18.0  0.900000
# 9          KAKAMEGA              52                  47.0  0.903846
# 10          KERICHO              14                   6.0  0.428571
# 11           KIAMBU              39                  37.0  0.948718
# 12           KILIFI              15                  14.0  0.933333
# 13        KIRINYAGA              16                  16.0  1.000000
# 14            KISII              34                  32.0  0.941176
# 15           KISUMU              79                  75.0  0.949367
# 16            KITUI              35                  35.0  1.000000
# 17            KWALE              16                  13.0  0.812500
# 18         LAIKIPIA              21                  20.0  0.952381
# 19         MACHAKOS              40                  38.0  0.950000
# 20          MAKUENI              33                  33.0  1.000000
# 21             MERU              32                  15.0  0.468750
# 22           MIGORI              50                  50.0  1.000000
# 23          MOMBASA              36                  24.0  0.666667
# 24         MURANG'A              30                  30.0  1.000000
# 25          NAIROBI             129                  97.0  0.751938
# 26           NAKURU              28                  26.0  0.928571
# 27            NANDI              19                   4.0  0.210526
# 28            NAROK              20                  11.0  0.550000
# 29          NYAMIRA              40                  39.0  0.975000
# 30        NYANDARUA              19                  11.0  0.578947
# 31            NYERI              34                  28.0  0.823529
# 32          SAMBURU               6                   6.0  1.000000
# 33            SIAYA             135                 127.0  0.940741
# 34     TAITA TAVETA              18                  15.0  0.833333
# 35    THARAKA-NITHI              13                  11.0  0.846154
# 36      TRANS NZOIA              18                  14.0  0.777778
# 37          TURKANA              19                  11.0  0.578947
# 38      UASIN GISHU              21                  20.0  0.952381
# 39           VIHIGA              23                  22.0  0.956522
# 40       WEST POKOT               6                   3.0  0.500000
#
#     CT Consistency  Consistency%
# 0             11.0      1.000000
# 1              3.0      0.130435
# 2             23.0      0.958333
# 3             17.0      0.739130
# 4              3.0      0.333333
# 5              6.0      0.285714
# 6             76.0      0.447059
# 7              0.0      0.000000
# 8             18.0      0.900000
# 9             43.0      0.826923
# 10             2.0      0.142857
# 11            18.0      0.461538
# 12            14.0      0.933333
# 13            14.0      0.875000
# 14            30.0      0.882353
# 15            68.0      0.860759
# 16            33.0      0.942857
# 17             9.0      0.562500
# 18            19.0      0.904762
# 19            27.0      0.675000
# 20            29.0      0.878788
# 21             9.0      0.281250
# 22            45.0      0.900000
# 23            18.0      0.500000
# 24            29.0      0.966667
# 25            64.0      0.496124
# 26            23.0      0.821429
# 27             1.0      0.052632
# 28             6.0      0.300000
# 29            38.0      0.950000
# 30            11.0      0.578947
# 31            27.0      0.794118
# 32             6.0      1.000000
# 33           110.0      0.814815
# 34            10.0      0.555556
# 35             7.0      0.538462
# 36            14.0      0.777778
# 37             7.0      0.368421
# 38            19.0      0.904762
# 39            22.0      0.956522
# 40             1.0      0.166667

# %% [markdown]
# ### Reporting Rates by Partner

# %%
byPartner=(result.groupby(['DisplayMechanism'])
   .agg({'DisplayMechanism':'count','uploadedCT': 'sum','UploadedConsistently':'sum'})
   .rename(columns={'DisplayMechanism':'ExpectedUpload','uploadedCT' : 'CT Recently Uploaded','UploadedConsistently' : 'CT Consistency' })
         )
byPartner.reset_index(inplace=True)# Flatten the table
byPartner['Recency%']=(byPartner['CT Recently Uploaded']/byPartner['ExpectedUpload'])
byPartner['Consistency%']=(byPartner['CT Consistency']/byPartner['ExpectedUpload'])
byPartner=byPartner [['DisplayMechanism','ExpectedUpload','CT Recently Uploaded','Recency%','CT Consistency','Consistency%']]

# %% [markdown]
# ### Save the data to Excel

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
rrperiod=str(calendar.month_abbr[FromDate.month])+str(FromDate.year)
filename='CTReportingRates_mysql_'+str(rrperiod)+".xlsx"

# %%
writer = pd.ExcelWriter(filename, engine='xlsxwriter')

# Write each dataframe to a different worksheet.
result.to_excel(writer, sheet_name='LineList')
byCounty.to_excel(writer, sheet_name='ByCounty')
byPartner.to_excel(writer, sheet_name='ByPartner')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
