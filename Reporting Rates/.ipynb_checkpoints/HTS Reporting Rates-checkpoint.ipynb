# %% [markdown]
# <h1><center> HTS Reporting Rates </center></h1>

# %%
import pandas as pd
import numpy as np
import calendar

# %%
# Declare the From and To Dates
FromDate = pd.to_datetime("2021-05-01")
ToDate = pd.to_datetime("2021-05-31")
# ToDate = pd.to_datetime(FromDate) + pd.offsets.MonthEnd()+pd.DateOffset(days=5)
print('From Date: ',FromDate,'To Date: ',ToDate)
# Out:
# From Date:  2021-05-01 00:00:00 To Date:  2021-05-31 00:00:00

# %% [markdown]
# ### Import the data
# - This is data on reporting for all the Active EHTS Sites and those that reported in the last 12 months

# %%
rr = pd.read_csv("C:/Users/Admin/Desktop/Reporting Rates/ReportingRatesHTS_Mysql.csv")
rr.head()
# Out:
#    DisplayMFL       DisplayFacilityName DisplayCounty DisplayMechanism  \
# 0       11936  ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 1       11936  ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 2       11936  ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 3       11936  ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 4       11936  ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
#
#   DisplayAgency  SiteCode  UploadDate Upload_monthYear  MPI_SiteCode  \
# 0           CDC   11936.0  04/02/2021           Apr-21       11936.0
# 1           CDC   11936.0  08/07/2020           Aug-20           NaN
# 2           CDC   11936.0  12/10/2020           Dec-20       11936.0
# 3           CDC   11936.0  02/10/2021           Feb-21       11936.0
# 4           CDC   11936.0  01/22/2021           Jan-21       11936.0
#
#   UploadDate_MPI Upload_monthYear_MPI
# 0     04/02/2021               Apr-21
# 1            NaN                  NaN
# 2     12/10/2020               Dec-20
# 3     02/10/2021               Feb-21
# 4     01/22/2021               Jan-21

# %%
rr.shape
# Out:
# (4085, 11)

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4085 entries, 0 to 4084
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DisplayMFL            4085 non-null   int64
#  1   DisplayFacilityName   4085 non-null   object
#  2   DisplayCounty         4085 non-null   object
#  3   DisplayMechanism      4085 non-null   object
#  4   DisplayAgency         4083 non-null   object
#  5   SiteCode              4035 non-null   float64
#  6   UploadDate            4035 non-null   object
#  7   Upload_monthYear      4035 non-null   object
#  8   MPI_SiteCode          2684 non-null   float64
#  9   UploadDate_MPI        2684 non-null   object
#  10  Upload_monthYear_MPI  2684 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 351.2+ KB

# %% [markdown]
# ### Data Cleaning
# - Convert Dates to correct data types
# - Replace NULL with NA's
# - Remove Duplicates (Grouped by MFLCode and UploadDate)

# %%
rr=rr.replace({'NULL':np.NaN})

# %%
# Columns with NULLS
rr.columns[rr.isna().any()].tolist()
# Out:
# ['DisplayAgency',
#  'SiteCode',
#  'UploadDate',
#  'Upload_monthYear',
#  'MPI_SiteCode',
#  'UploadDate_MPI',
#  'Upload_monthYear_MPI']

# %%
#convert the upload_date and Upload_date MPI field from object to datetime datatype
rr['UploadDate'] = pd.to_datetime(rr['UploadDate'])
rr['UploadDate_MPI'] = pd.to_datetime(rr['UploadDate_MPI'])

# %%
rr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4085 entries, 0 to 4084
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DisplayMFL            4085 non-null   int64
#  1   DisplayFacilityName   4085 non-null   object
#  2   DisplayCounty         4085 non-null   object
#  3   DisplayMechanism      4085 non-null   object
#  4   DisplayAgency         4083 non-null   object
#  5   SiteCode              4035 non-null   float64
#  6   UploadDate            4035 non-null   datetime64[ns]
#  7   Upload_monthYear      4035 non-null   object
#  8   MPI_SiteCode          2684 non-null   float64
#  9   UploadDate_MPI        2684 non-null   datetime64[ns]
#  10  Upload_monthYear_MPI  2684 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(1), object(6)
# memory usage: 351.2+ KB

# %%
rr.tail()
# Out:
#       DisplayMFL          DisplayFacilityName DisplayCounty DisplayMechanism  \
# 4080       17242            KAMOLO DISPENSARY         BUSIA             IRDO
# 4081       15968  LUKOLIS MODEL HEALTH CENTRE         BUSIA             IRDO
# 4082       15968  LUKOLIS MODEL HEALTH CENTRE         BUSIA             IRDO
# 4083       15968  LUKOLIS MODEL HEALTH CENTRE         BUSIA             IRDO
# 4084       16087            OBEKAI DISPENSARY         BUSIA             IRDO
#
#      DisplayAgency  SiteCode UploadDate Upload_monthYear  MPI_SiteCode  \
# 4080           CDC   17242.0 2020-09-15           Sep-20           NaN
# 4081           CDC   15968.0 2020-08-26           Aug-20           NaN
# 4082           CDC   15968.0 2020-11-30           Nov-20           NaN
# 4083           CDC   15968.0 2020-09-15           Sep-20           NaN
# 4084           CDC       NaN        NaT              NaN           NaN
#
#      UploadDate_MPI Upload_monthYear_MPI
# 4080            NaT                  NaN
# 4081            NaT                  NaN
# 4082            NaT                  NaN
# 4083            NaT                  NaN
# 4084            NaT                  NaN

# %%
#Create a concatenated column to differentiate the multi-partner supported HTS Sites
rr['UnikSite']=rr['DisplayMFL'].map(str) + '/' + rr['DisplayMechanism'].map(str)

# %%
rr['UnikSite'].sample
# Out:
# <bound method NDFrame.sample of 0       11936/CHS NAISHI
# 1       11936/CHS NAISHI
# 2       11936/CHS NAISHI
# 3       11936/CHS NAISHI
# 4       11936/CHS NAISHI
#               ...
# 4080          17242/IRDO
# 4081          15968/IRDO
# 4082          15968/IRDO
# 4083          15968/IRDO
# 4084          16087/IRDO
# Name: UnikSite, Length: 4076, dtype: object>

# %%
#Remove Duplicates from original dataset - Unique Site with 1 Upload Date, upload MPI
rr = rr.drop_duplicates(subset=["UnikSite","UploadDate"])
rr.shape
# Out:
# (4076, 12)

# %%
# Create a column called UploadedCT & UploadedMPI
rr['uploadedHTS'] = np.where(rr.UploadDate.isnull(),0,1)
rr['UploadedMPI'] = np.where(rr.UploadDate_MPI.isnull(),0,1)

# %% [markdown]
# ### Summary Statistics
# - How many Unique Facilities do we have (Number of Sites - Duplicates)

# %%
# Number of Unique EMR Sites - Denominator/ Expected Uploads
len(pd.unique(rr['UnikSite']))
# Out:
# 590

# %% [markdown]
# <h2><center> Expected Uploads </center></h2>

# %%
#Create a data Frame to hold distinct list of sites for the denominator / Baseline EMR Sites
#We will use later for left joining
rr_denom = rr.drop_duplicates(subset=['UnikSite'])
rr_denom=rr_denom[['UnikSite','DisplayMFL','DisplayFacilityName','DisplayCounty','DisplayMechanism','DisplayAgency']]
rr_denom.head()
# Out:
#                      UnikSite  DisplayMFL          DisplayFacilityName  \
# 0            11936/CHS NAISHI       11936     ATHI RIVER HEALTH CENTRE
# 13      12881/CHAK CHAP UZIMA       12881  BARAKA DISPENSARY (NAIROBI)
# 15      11265/CHAK CHAP UZIMA       11265          BURA MISSION CLINIC
# 25      23285/CHAK CHAP UZIMA       23285              CHAANI CATHOLIC
# 35  19504/AMREF NAIROBI KITUI       19504           CHILD DOCTOR KENYA
#
#    DisplayCounty     DisplayMechanism DisplayAgency
# 0       MACHAKOS           CHS NAISHI           CDC
# 13       NAIROBI      CHAK CHAP UZIMA           CDC
# 15  TAITA TAVETA      CHAK CHAP UZIMA           CDC
# 25       MOMBASA      CHAK CHAP UZIMA           CDC
# 35       NAIROBI  AMREF NAIROBI KITUI           CDC

# %%
rr_denom.shape
# Out:
# (590, 6)

# %% [markdown]
# <h2><center> HTS RECENCY </center></h2>

# %%
#Filter the Original RR Data to the specific RR Period (FromDate ToDate)
mask = (rr['UploadDate'] >= FromDate) & (rr['UploadDate'] <= ToDate)
recency=rr.loc[mask]
recency.shape
# Out:
# (422, 14)

# %%
#Number of Duplicates in CT_Recency Those that reported in the reporting month and between 1st and 5th of next month
len(recency['UnikSite'])- len(pd.unique(recency['UnikSite']))
# Out:
# 0

# %%
#Remove duplicates.Making Sure we are counting a site only once within the reporting period being looked at
recency = recency.drop_duplicates(subset=["UnikSite"])
recency.shape
# Out:
# (422, 14)

# %%
#Join the CT Recency Dataset to the EMR Sites Denominator - #Left Join
result = pd.merge(rr_denom,
                 recency[['UnikSite','DisplayMFL', 'UploadDate','uploadedHTS']],
                 on='UnikSite', 
                 how='left')
result.shape
# Out:
# (590, 9)

# %% [markdown]
# <h2><center> HTS CONSISTENCY </center></h2>

# %%
# Define Period to compute 
consist_FromDate=pd.to_datetime(FromDate)-pd.DateOffset(months=2)
print('Consistency Period - From Date: ',consist_FromDate,'To Date: ',ToDate)
# Out:
# Consistency Period - From Date:  2021-03-01 00:00:00 To Date:  2021-05-31 00:00:00

# %%
#Filter the data to return - only sites that have Uploaded every month last 3 months
const = (rr['UploadDate'] >= consist_FromDate) & (rr['UploadDate'] <= ToDate)
consistency=rr.loc[const]
consistency.head()
# Out:
#     DisplayMFL          DisplayFacilityName DisplayCounty DisplayMechanism  \
# 0        11936     ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 8        11936     ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 9        11936     ATHI RIVER HEALTH CENTRE      MACHAKOS       CHS NAISHI
# 13       12881  BARAKA DISPENSARY (NAIROBI)       NAIROBI  CHAK CHAP UZIMA
# 22       11265          BURA MISSION CLINIC  TAITA TAVETA  CHAK CHAP UZIMA
#
#    DisplayAgency  SiteCode UploadDate Upload_monthYear  MPI_SiteCode  \
# 0            CDC   11936.0 2021-04-02           Apr-21       11936.0
# 8            CDC   11936.0 2021-03-03           Mar-21       11936.0
# 9            CDC   11936.0 2021-05-06           May-21       11936.0
# 13           CDC   12881.0 2021-05-21           May-21       12881.0
# 22           CDC   11265.0 2021-05-18           May-21       11265.0
#
#    UploadDate_MPI Upload_monthYear_MPI               UnikSite  uploadedHTS  \
# 0      2021-04-02               Apr-21       11936/CHS NAISHI            1
# 8      2021-03-03               Mar-21       11936/CHS NAISHI            1
# 9      2021-05-06               May-21       11936/CHS NAISHI            1
# 13     2021-05-06               May-21  12881/CHAK CHAP UZIMA            1
# 22     2021-05-18               May-21  11265/CHAK CHAP UZIMA            1
#
#     UploadedMPI
# 0             1
# 8             1
# 9             1
# 13            1
# 22            1

# %%
#Pivot the Data then add instances of uploads by month, filter only those that uploaded all 3 months
cs=pd.pivot_table(consistency, values='uploadedHTS', 
                    columns=['Upload_monthYear'],
                    index=['UnikSite','DisplayMFL'])

cs = cs.replace(np.nan, 0)
cs['UploadedConsistently']=cs.sum(axis=1) 
cs = cs.loc[(cs['UploadedConsistently']>=3)] 
cs.reset_index(inplace=True)# Flatten the table

#If Uploaded consistently is NULL then 0 other wise 1
cs['UploadedConsistently'] = np.where(cs.UploadedConsistently.isnull(),0,1)

cs
# Out:
# Upload_monthYear                    UnikSite  DisplayMFL  Apr-21  Mar-21  \
# 0                      10267/CHAK CHAP UZIMA       10267     1.0     1.0
# 1                      10545/UON CRISSP PLUS       10545     1.0     1.0
# 2                      10602/CHAK CHAP UZIMA       10602     1.0     1.0
# 3                    10686/CHS TEGEMEZA PLUS       10686     1.0     1.0
# 4                      10765/UON CRISSP PLUS       10765     1.0     1.0
# ..                                       ...         ...     ...     ...
# 255               21117/HOPE WORLDWIDE KENYA       21117     1.0     1.0
# 256                         21220/LVCT STEPS       21220     1.0     1.0
# 257                       22476/EGPAF TIMIZA       22476     1.0     1.0
# 258               24552/HOPE WORLDWIDE KENYA       24552     1.0     1.0
# 259                       25260/EGPAF TIMIZA       25260     1.0     1.0
#
# Upload_monthYear  May-21  UploadedConsistently
# 0                    1.0                     1
# 1                    1.0                     1
# 2                    1.0                     1
# 3                    1.0                     1
# 4                    1.0                     1
# ..                   ...                   ...
# 255                  1.0                     1
# 256                  1.0                     1
# 257                  1.0                     1
# 258                  1.0                     1
# 259                  1.0                     1
#
# [260 rows x 6 columns]

# %%
#Join the Consistency Dataset to the CT Recency - #Left Join
result = pd.merge(result,
                 cs[['UnikSite', 'UploadedConsistently']],
                 on='UnikSite', 
                 how='left')
result.shape
# Out:
# (590, 10)

# %%
result=result[['UnikSite','DisplayMFL_x','DisplayFacilityName','DisplayCounty','DisplayMechanism','DisplayAgency','UploadDate','uploadedHTS','UploadedConsistently']]
result
# Out:
#                       UnikSite  DisplayMFL_x          DisplayFacilityName  \
# 0             11936/CHS NAISHI         11936     ATHI RIVER HEALTH CENTRE
# 1        12881/CHAK CHAP UZIMA         12881  BARAKA DISPENSARY (NAIROBI)
# 2        11265/CHAK CHAP UZIMA         11265          BURA MISSION CLINIC
# 3        23285/CHAK CHAP UZIMA         23285              CHAANI CATHOLIC
# 4    19504/AMREF NAIROBI KITUI         19504           CHILD DOCTOR KENYA
# ..                         ...           ...                          ...
# 585                 20029/IRDO         20029                   SINDO DICE
# 586                 15800/IRDO         15800        ANGURAI HEALTH CENTRE
# 587                 17242/IRDO         17242            KAMOLO DISPENSARY
# 588                 15968/IRDO         15968  LUKOLIS MODEL HEALTH CENTRE
# 589                 16087/IRDO         16087            OBEKAI DISPENSARY
#
#     DisplayCounty     DisplayMechanism DisplayAgency UploadDate  uploadedHTS  \
# 0        MACHAKOS           CHS NAISHI           CDC 2021-05-06          1.0
# 1         NAIROBI      CHAK CHAP UZIMA           CDC 2021-05-21          1.0
# 2    TAITA TAVETA      CHAK CHAP UZIMA           CDC 2021-05-18          1.0
# 3         MOMBASA      CHAK CHAP UZIMA           CDC 2021-05-17          1.0
# 4         NAIROBI  AMREF NAIROBI KITUI           CDC 2021-05-19          1.0
# ..            ...                  ...           ...        ...          ...
# 585      HOMA BAY                 IRDO           CDC        NaT          NaN
# 586         BUSIA                 IRDO           CDC        NaT          NaN
# 587         BUSIA                 IRDO           CDC        NaT          NaN
# 588         BUSIA                 IRDO           CDC        NaT          NaN
# 589         BUSIA                 IRDO           CDC        NaT          NaN
#
#      UploadedConsistently
# 0                     1.0
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 585                   NaN
# 586                   NaN
# 587                   NaN
# 588                   NaN
# 589                   NaN
#
# [590 rows x 9 columns]

# %% [markdown]
# ### HTS Reporting Rates by County

# %%
byCounty=(result.groupby(['DisplayCounty'])
   .agg({'DisplayCounty':'count','uploadedHTS': 'sum','UploadedConsistently':'sum'})
   .rename(columns={'DisplayCounty':'ExpectedUpload','uploadedHTS' : 'CT Recently Uploaded','UploadedConsistently' : 'CT Consistency' })
         )
byCounty.reset_index(inplace=True)# Flatten the table
byCounty['Recency%']=(byCounty['CT Recently Uploaded']/byCounty['ExpectedUpload'])
byCounty['Consistency%']=(byCounty['CT Consistency']/byCounty['ExpectedUpload'])
byCounty=byCounty [['DisplayCounty','ExpectedUpload','CT Recently Uploaded','Recency%','CT Consistency','Consistency%']]
byCounty
# Out:
#     DisplayCounty  ExpectedUpload  CT Recently Uploaded  Recency%  \
# 0           BOMET               1                   0.0  0.000000
# 1         BUNGOMA               2                   2.0  1.000000
# 2           BUSIA               5                   1.0  0.200000
# 3            EMBU               1                   1.0  1.000000
# 4        HOMA BAY             167                 117.0  0.700599
# 5         KAJIADO               1                   1.0  1.000000
# 6        KAKAMEGA               3                   3.0  1.000000
# 7          KIAMBU              21                  15.0  0.714286
# 8          KILIFI               1                   1.0  1.000000
# 9       KIRINYAGA               6                   5.0  0.833333
# 10          KISII              32                  31.0  0.968750
# 11         KISUMU              47                  30.0  0.638298
# 12          KITUI              21                  21.0  1.000000
# 13          KWALE               2                   0.0  0.000000
# 14       MACHAKOS              35                  26.0  0.742857
# 15        MAKUENI              21                  16.0  0.761905
# 16         MIGORI              43                  41.0  0.953488
# 17        MOMBASA               5                   4.0  0.800000
# 18       MURANG'A               4                   3.0  0.750000
# 19        NAIROBI              47                  22.0  0.468085
# 20         NAKURU               3                   3.0  1.000000
# 21        NYAMIRA              35                  29.0  0.828571
# 22      NYANDARUA               1                   1.0  1.000000
# 23          NYERI               1                   1.0  1.000000
# 24          SIAYA              80                  44.0  0.550000
# 25   TAITA TAVETA               4                   3.0  0.750000
# 26  THARAKA-NITHI               1                   1.0  1.000000
#
#     CT Consistency  Consistency%
# 0              0.0      0.000000
# 1              0.0      0.000000
# 2              0.0      0.000000
# 3              1.0      1.000000
# 4             55.0      0.329341
# 5              1.0      1.000000
# 6              0.0      0.000000
# 7              5.0      0.238095
# 8              1.0      1.000000
# 9              2.0      0.333333
# 10            25.0      0.781250
# 11            15.0      0.319149
# 12            21.0      1.000000
# 13             0.0      0.000000
# 14            16.0      0.457143
# 15            14.0      0.666667
# 16            36.0      0.837209
# 17             3.0      0.600000
# 18             2.0      0.500000
# 19            12.0      0.255319
# 20             2.0      0.666667
# 21            14.0      0.400000
# 22             0.0      0.000000
# 23             1.0      1.000000
# 24            33.0      0.412500
# 25             0.0      0.000000
# 26             1.0      1.000000

# %% [markdown]
# ### HTS Reporting Rates by Partner

# %%
byPartner=(result.groupby(['DisplayMechanism'])
   .agg({'DisplayMechanism':'count','uploadedHTS': 'sum','UploadedConsistently':'sum'})
   .rename(columns={'DisplayMechanism':'ExpectedUpload','uploadedHTS' : 'CT Recently Uploaded','UploadedConsistently' : 'CT Consistency' })
         )
byPartner.reset_index(inplace=True)# Flatten the table
byPartner['Recency%']=(byPartner['CT Recently Uploaded']/byPartner['ExpectedUpload'])
byPartner['Consistency%']=(byPartner['CT Consistency']/byPartner['ExpectedUpload'])
byPartner=byPartner [['DisplayMechanism','ExpectedUpload','CT Recently Uploaded','Recency%','CT Consistency','Consistency%']]

# %% [markdown]
# ### Save the data to Excel

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
rrperiod=str(calendar.month_abbr[FromDate.month])+str(FromDate.year)
filename='HTSReportingRates_mysql_'+str(rrperiod)+".xlsx"

# %%
writer = pd.ExcelWriter(filename, engine='xlsxwriter')

# Write each dataframe to a different worksheet.
result.to_excel(writer, sheet_name='LineList')
byCounty.to_excel(writer, sheet_name='ByCounty')
byPartner.to_excel(writer, sheet_name='ByPartner')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
